# %% [markdown]
# # Chapter 6: Data loading, storage, and file formats

# %%
# Setup
import pandas as pd
import numpy as np

import requests
import os
import sys
import json
import lxml

# %% [markdown]
# ## 6.1: Reading and writing data in text format

# %% [markdown]
# Similar to the tidyverse ecosystem, pandas has several functions for reading data from different formats (e.g., csv) into DataFrames.  These functions can handle type inference (determining if data should be interpreted as strings, numeric, etc), parsing dates and times, and skipping over headers and footers.
#
# To use the examples from the textbook, we need to download the files from the [GitHub repository](https://github.com/wesm/pydata-book).

# %%
# Download the first example file
url = 'https://raw.githubusercontent.com/wesm/pydata-book/2nd-edition/examples/ex1.csv'
request = requests.get(url)

# %%
if request.status_code == 200:
    with open('ch06_ex01.csv', 'w') as f:
        f.write(request.text)

# %%
# Read into DataFrame
ex1_df = pd.read_csv('ch06_ex01.csv')
ex1_df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# We can specify column names ourselves, very similar to tidyverse
names = ['A', 'B', 'C', 'D', 'message']
pd.read_csv('ch06_ex01.csv', names=names)
# Out:
#    A   B   C   D  message
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
# If you have a file with missing data, we can specify which values should be recoded as NA
url = 'https://raw.githubusercontent.com/wesm/pydata-book/2nd-edition/examples/ex5.csv'
request = requests.get(url)

# %%
if request.status_code == 200:
    with open('ch06_ex05.csv', 'w') as f:
        f.write(request.text)

# %%
df = pd.read_csv('ch06_ex05.csv', na_values=['NA', 'foo'])
df
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     NaN

# %%
# If we want to read chunks of data, we can read just a few lines
pd.read_csv('ch06_ex05.csv', nrows=1)
# Out:
#   something  a  b  c  d  message
# 0       one  1  2  3  4      NaN

# %% [markdown]
# ### Writing data out to text format

# %%
# Data can be written as csv output
df.to_csv('ch06_ex05_output.csv')

# %%
# Read back in the same file
pd.read_csv('ch06_ex05_output.csv')
# Out:
#    Unnamed: 0 something  a   b     c   d message
# 0           0       one  1   2   3.0   4     NaN
# 1           1       two  5   6   NaN   8   world
# 2           2     three  9  10  11.0  12     NaN

# %%
# We can specify how we want missing values to be handled
df.to_csv('ch06_ex05_output.csv', na_rep='NULL')

# %%
# Read back in the same file-- specify sentinel for missing data
pd.read_csv('ch06_ex05_output.csv', na_values='NULL')
# Out:
#    Unnamed: 0 something  a   b     c   d message
# 0           0       one  1   2   3.0   4     NaN
# 1           1       two  5   6   NaN   8   world
# 2           2     three  9  10  11.0  12     NaN

# %%
# If we want to experiment with different methods, use sys.stdout to print to screen
df.to_csv(sys.stdout, na_rep='NULL', index=False)
# Out:
# something,a,b,c,d,message
# one,1,2,3.0,4,NULL
# two,5,6,NULL,8,world
# three,9,10,11.0,12,NULL

# %% [markdown]
# ### JSON data

# %%
# Create example JSON data-- parser expects double quotes
obj = """
{"name": "Wes",
"places_lived": ["United States", "Spain", "Germany"],
"pet": null,
"siblings": [{"name": "Scott", "age": 25, "pet": "Zuko"},
{"name": "Katie", "age": 33, "pet": "Cisco"}]
}
"""

# %%
# Load JSON data
result = json.loads(obj)
result
# Out:
# {'name': 'Wes',
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 25, 'pet': 'Zuko'},
#   {'name': 'Katie', 'age': 33, 'pet': 'Cisco'}]}

# %%
# Create an example DataFrame of siblings
pd.DataFrame(result['siblings'], columns=['name', 'age', 'pet'])
# Out:
#     name  age    pet
# 0  Scott   25   Zuko
# 1  Katie   33  Cisco

# %% [markdown]
# ### XML and HTML: web scraping

# %% [markdown]
# The textbook example for scraping XML data from New York Metro website is quite outdated, so I'll skip this section for now and add to it later when needed.

# %% [markdown]
# ## 6.2: Binary data formats

# %% [markdown]
# Python has a built in method called `pickel` serialization to store complex data structures in linear format that can be stored locally or transmitted over a network (similar to R's RDS).  This will allow us to write data in `pickel` format, then parse the data back as a DataFrame `pandas.load()`.

# %% [markdown]
# Another option for storing large amounts of complex data is HDF5 (hierarchical data format 5).  HDF5 files contain an internal node-like format that connects data and associated metadata, similar to how files might be stored on your computer.

# %% [markdown]
# ## 6.3 Interacting with HTML and web APIs

# %% [markdown]
# The second addition of the textbook uses the GitHub API in an example, which I'll also use here.

# %%
# Grab the last 30 pandas issues on GitHub
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)

if resp.status_code == 200:
    print('Download successful!')
else:
    print('Error: Check connection or URL.')
# Out:
# Download successful!

# %%
# Parse JSON data
data = resp.json()

# Get the title of the first issue
data[0]['title']
# Out:
# 'BUG attempt to fix GH46575'

# %%
# Each entry is a dictionary
data[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46644',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46644/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46644/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46644/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/46644',
#  'id': 1193371305,
#  'node_id': 'PR_kwDOAA0YD841qzcs',
#  'number': 46644,
#  'title': 'BUG attempt to fix GH46575',
#  'user': {'login': 'arnaudlegout',
#   'id': 7670869,
#   'node_id': 'MDQ6VXNlcjc2NzA4Njk=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/7670869?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/arnaudlegout',
#   'html_url': 'https://github.com/arnaudlegout',
#   'followers_url': 'https://api.github.com/users/arnaudlegout/followers',
#   'following_url': 'https://api.github.com/users/arnaudlegout/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/arnaudlegout/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/arnaudlegout/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/arnaudlegout/subscriptions',
#   'organizations_url': 'https://api.github.com/users/arnaudlegout/orgs',
#   'repos_url': 'https://api.github.com/users/arnaudlegout/repos',
#   'events_url': 'https://api.github.com/users/arnaudlegout/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/arnaudlegout/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'labels': [],
#  'state': 'open',
#  'locked': False,
#  'assignee': None,
#  'assignees': [],
#  'milestone': None,
#  'comments': 1,
#  'created_at': '2022-04-05T15:45:25Z',
#  'updated_at': '2022-04-05T15:50:28Z',
#  'closed_at': None,
#  'author_association': 'NONE',
#  'active_lock_reason': None,
#  'draft': True,
#  'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46644',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46644',
#   'diff_url': 'https://github.com/pandas-dev/pandas/pull/46644.diff',
#   'patch_url': 'https://github.com/pandas-dev/pandas/pull/46644.patch',
#   'merged_at': None},
#  'body': '- [ ] closes #46575 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#  'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46644/reactions',
#   'total_count': 0,
#   '+1': 0,
#   '-1': 0,
#   'laugh': 0,
#   'hooray': 0,
#   'confused': 0,
#   'heart': 0,
#   'rocket': 0,
#   'eyes': 0},
#  'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46644/timeline',
#  'performed_via_github_app': None}

# %%
# Grab the number, title, labes, state, crated_at, updated_at, and closed_at fields
github_issues = pd.DataFrame(data, columns=['number', 'title', 'labels', 'state', 'created_at', 'updated_at', 'closed_at'])
github_issues
# Out:
#     number                                              title  \
# 0    46644                         BUG attempt to fix GH46575
# 1    46643                         Meta issue: CI refactoring
# 2    46642                             DOC: .bfill() (#46631)
# 3    46641             added test for replace with value none
# 4    46640                 homogeneous Period targets bug fix
# 5    46638           TYP: tighten return type in function any
# 6    46636   REGR: Replace changes the dtype of other columns
# 7    46635                                               ENH:
# 8    46634    BUG: Replace changes the dtype of other columns
# 9    46632  BUG: Getting different column types for DataFr...
# 10   46631                        DOC: simply method='bfill'?
# 11   46630            BUG: Join ValueError for DataFrame list
# 12   46629            BUG: added finalize to explode, GH28283
# 13   46628                               Fix NaN bug in ujson
# 14   46627                                              BUG:
# 15   46625  Backport PR #46602 on branch 1.4.x (CI/TST: Ma...
# 16   46624  Remove references to previously-vendored Sphin...
# 17   46623                BUG: SeriesGroupBy apply wrong name
# 18   46622  ENH: Join - Add a parameter to check for dupli...
# 19   46620  DOC: documentation on `.loc[]` needs some clar...
# 20   46619  BUG: Pandas rolling removes imaginary part of ...
# 21   46618  BUG:  test_binops fails in multiple variations...
# 22   46616         TYP: how to annotate DataFrame.__getitem__
# 23   46615  DOC: can't switch to the docs for a different ...
# 24   46613  ENH: Interval.__contains__(self, other: Interval)
# 25   46611                              Add Windows GHA build
# 26   46610                                         RLS: 1.4.3
# 27   46606  BUG: DataFrame.replace with dict doesn't work ...
# 28   46603                                      TYP: na_value
# 29   46601  WIP/BUG: algorithms.factorize moves null value...
#
#                                                labels state  \
# 0                                                  []  open
# 1   [{'id': 127681, 'node_id': 'MDU6TGFiZWwxMjc2OD...  open
# 2                                                  []  open
# 3                                                  []  open
# 4                                                  []  open
# 5                                                  []  open
# 6   [{'id': 32815646, 'node_id': 'MDU6TGFiZWwzMjgx...  open
# 7   [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 8   [{'id': 32815646, 'node_id': 'MDU6TGFiZWwzMjgx...  open
# 9   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 10  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 11                                                 []  open
# 12                                                 []  open
# 13                                                 []  open
# 14  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 15                                                 []  open
# 16  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 17                                                 []  open
# 18  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 19  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 20  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 21  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 22  [{'id': 219960758, 'node_id': 'MDU6TGFiZWwyMTk...  open
# 23  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 24  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 25  [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 26  [{'id': 131473665, 'node_id': 'MDU6TGFiZWwxMzE...  open
# 27  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 28                                                 []  open
# 29  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
#
#               created_at            updated_at closed_at
# 0   2022-04-05T15:45:25Z  2022-04-05T15:50:28Z      None
# 1   2022-04-05T07:10:28Z  2022-04-05T08:36:33Z      None
# 2   2022-04-05T04:23:38Z  2022-04-05T15:49:04Z      None
# 3   2022-04-05T03:25:52Z  2022-04-05T03:25:55Z      None
# 4   2022-04-04T20:38:46Z  2022-04-04T20:38:48Z      None
# 5   2022-04-04T19:46:16Z  2022-04-05T12:27:27Z      None
# 6   2022-04-04T19:21:07Z  2022-04-05T17:18:00Z      None
# 7   2022-04-04T18:36:22Z  2022-04-05T08:41:48Z      None
# 8   2022-04-04T16:11:41Z  2022-04-05T09:24:53Z      None
# 9   2022-04-04T10:37:46Z  2022-04-04T10:37:46Z      None
# 10  2022-04-04T08:29:56Z  2022-04-05T03:52:21Z      None
# 11  2022-04-03T21:17:45Z  2022-04-05T15:52:03Z      None
# 12  2022-04-03T21:04:52Z  2022-04-03T22:21:59Z      None
# 13  2022-04-03T20:40:39Z  2022-04-04T16:01:50Z      None
# 14  2022-04-03T20:37:34Z  2022-04-03T20:37:34Z      None
# 15  2022-04-03T16:08:31Z  2022-04-03T16:08:31Z      None
# 16  2022-04-03T12:16:28Z  2022-04-04T22:40:46Z      None
# 17  2022-04-03T11:45:44Z  2022-04-03T13:22:03Z      None
# 18  2022-04-03T10:14:45Z  2022-04-03T16:09:18Z      None
# 19  2022-04-03T03:57:28Z  2022-04-03T15:35:52Z      None
# 20  2022-04-03T02:40:20Z  2022-04-03T18:44:43Z      None
# 21  2022-04-02T22:58:53Z  2022-04-03T19:22:25Z      None
# 22  2022-04-02T14:52:26Z  2022-04-05T00:28:54Z      None
# 23  2022-04-02T14:29:07Z  2022-04-05T15:26:44Z      None
# 24  2022-04-02T11:51:50Z  2022-04-04T08:29:01Z      None
# 25  2022-04-02T10:39:41Z  2022-04-05T17:14:54Z      None
# 26  2022-04-02T09:38:26Z  2022-04-02T09:38:26Z      None
# 27  2022-04-01T19:35:53Z  2022-04-03T15:01:49Z      None
# 28  2022-04-01T18:24:17Z  2022-04-01T18:24:17Z      None
# 29  2022-04-01T16:46:57Z  2022-04-02T02:28:32Z      None
